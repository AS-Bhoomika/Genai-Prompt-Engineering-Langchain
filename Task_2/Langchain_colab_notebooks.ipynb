# %%
# !pip install -qU langchain langchain-core langchain-community langchain-openai openai faiss-cpu pypdf
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002303734AE40>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/langchain/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000023037371A90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/langchain/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000023037371D10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/langchain/
# ...

# %%
import os
from langchain_core.prompts import PromptTemplate

# %%
print("LangChain is a framework for building AI applications.")
print("It helps create chatbots, tools, memory systems, and workflows.")
# Out:
# LangChain is a framework for building AI applications.
# It helps create chatbots, tools, memory systems, and workflows.

# %%
prompt = PromptTemplate.from_template("Explain {topic} in simple words.")

result = prompt.format(topic="LangChain")
print(result)
# Out:
# Explain LangChain in simple words.

# %%
chat_history = []

chat_history.append(("Hi", "Hello"))
chat_history.append(("My name is Vinay", "Nice to meet you"))

print(chat_history)
# Out:
# [('Hi', 'Hello'), ('My name is Vinay', 'Nice to meet you')]

# %%
def simple_chain(text):
    return f"Processed Output: {text.upper()}"

print(simple_chain("hello langchain"))
# Out:
# Processed Output: HELLO LANGCHAIN

# %%
def calculator(a, b):
    return a + b

print("Calculator Output:", calculator(10, 5))
# Out:
# Calculator Output: 15

# %%
sample_text = "LangChain helps read documents like PDF, TXT, CSV."

print(sample_text)
# Out:
# LangChain helps read documents like PDF, TXT, CSV.

# %%
documents = ["AI", "Machine Learning", "LangChain", "Python"]

query = "LangChain"
if query in documents:
    print("Relevant document found:", query)
# Out:
# Relevant document found: LangChain

# %%
print("""
User Input --> Prompt --> LLM --> Chain --> Tool/Agent --> Output
""")
# Out:
# User Input --> Prompt --> LLM --> Chain --> Tool/Agent --> Output

# %%
question = "What is AI?"
answer = "AI means machines that can learn and think."

print("Question:", question)
print("Answer:", answer)
# Out:
# Question: What is AI?
# Answer: AI means machines that can learn and think.

# %%
print("1. AI Chatbot")
print("2. Resume Screening")
print("3. PDF Question Answering")
# Out:
# 1. AI Chatbot
# 2. Resume Screening
# 3. PDF Question Answering

# %%
limitations = [
    "Complex for beginners",
    "API Cost",
    "Debugging chains can be difficult"
]

for item in limitations:
    print("-", item)
# Out:
# - Complex for beginners
# - API Cost
# - Debugging chains can be difficult

# %%
print("LangChain is powerful for building modern AI applications.")
print("Future Scope: LangGraph, Multi-Agent Systems, Enterprise AI")
# Out:
# LangChain is powerful for building modern AI applications.
# Future Scope: LangGraph, Multi-Agent Systems, Enterprise AI
